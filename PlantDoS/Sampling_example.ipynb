# %%
import numpy as np
import pandas as pd
import pickle
import copy
from sampling_method import random_sampling, population_annealing

# %%
with open('true_distribution_df_range21.pickle', 'rb') as p:
    true_distribution_df = pickle.load(p)

# %%
range_num = int(len(true_distribution_df)**(1/4))               #number of levels of each input parameters
rand_num = 20000                                                #number of sampling in each trials
trial_num = 5                                                   #number of trial

# %%
rs = random_sampling(true_distribution_df, range_num, rand_num)
random_sampling_df = rs.random_sample_from_df(trial_num)
random_sampling_df
# Out:
#         Conc  SM2_eq  Temp  Time  Total_failure  SM1_failure  SM2_failure  \
# 68805    3.5     4.5   0.0   4.5            1.0          1.0          1.0
# 160949   8.5     3.5  10.0   2.5            1.0          0.0          0.0
# 13270    0.5     4.5   0.5   9.5            1.0          1.0          1.0
# 39081    2.0     2.0   6.5   0.0            1.0          1.0          1.0
# 49792    2.5     3.5   9.5   0.5            1.0          1.0          1.0
# ...      ...     ...   ...   ...            ...          ...          ...
# 64874    3.5     0.0   1.0   2.5            1.0          1.0          1.0
# 77391    4.0     3.5   5.0   3.0            1.0          1.0          1.0
# 42447    2.0     6.0   2.5   3.0            1.0          1.0          1.0
# 133139   7.0     3.5   9.0  10.0            1.0          0.0          0.0
# 36411    1.5     9.5   5.5   9.0            1.0          1.0          1.0
#
#         Iso_failure  Bis_failure     Yield     E_factor  Material_cost  \
# 68805         0.000          0.0  0.164123   596.196728   27494.256291
# 160949        0.436          1.0  0.897972     8.972917     458.916228
# 13270         0.000          0.0  0.411982  1055.136111   48702.987167
# 39081         0.000          0.0  0.162713  1265.363282   58395.207729
# 49792         0.000          0.0  0.467542   342.638610   15849.027223
# ...             ...          ...       ...          ...            ...
# 64874         0.000          0.0  0.107636   909.290693   41917.727103
# 77391         0.000          0.0  0.562213   134.973471    6268.521293
# 42447         0.000          0.0  0.142912  1441.533055   66489.320447
# 133139        0.376          1.0  0.901553    18.777082     911.380639
# 36411         0.000          0.0  0.881825   298.574018   13821.853797
#
#                 STY  trial
# 68805      8.459700      0
# 160949  1532.774454      0
# 13270      0.388942      0
# 39081     37.587881      0
# 49792    108.005786      0
# ...             ...    ...
# 64874     15.081265      4
# 77391     78.773539      4
# 42447      7.366395      4
# 133139    17.095496      4
# 36411      1.762424      4
#
# [100000 rows x 14 columns]

# %%
range_num = int(len(true_distribution_df)**(1/4))  #number of levels of each input parameters
walk_step = 2                                      #number of random walk step (+-)
bnum = 10                                          #number of levels of inverse temperature
betas = np.linspace(0.1,20,num=bnum)               #inverse tenmeratures
mcmc_num = 20                                      #number of mcmc steps of each particles in one temperature
num_population = 100                               #number of population
trial_num = 5                                      #number of trial

# %%
pa = population_annealing(true_distribution_df,range_num,num_population,mcmc_num,walk_step,betas)
EPA_sampling_df, _ = pa.pupolation_annealing_from_df(trial_num)
EPA_sampling_df
# Out:
#         Conc  SM2_eq  Temp  Time  Total_failure  SM1_failure  SM2_failure  \
# 152767   8.0     5.0   4.0   6.5          1.000          0.0        0.923
# 152767   8.0     5.0   4.0   6.5          1.000          0.0        0.923
# 162028   8.5     5.0   4.0   6.5          0.939          0.0        0.010
# 170848   9.0     4.5   4.0   6.5          0.983          0.0        0.000
# 152767   8.0     5.0   4.0   6.5          1.000          0.0        0.923
# ...      ...     ...   ...   ...            ...          ...          ...
# 130681   7.0     1.0   3.0   9.5          0.048          0.0        0.000
# 130681   7.0     1.0   3.0   9.5          0.048          0.0        0.000
# 130681   7.0     1.0   3.0   9.5          0.048          0.0        0.000
# 130681   7.0     1.0   3.0   9.5          0.048          0.0        0.000
# 148762   8.0     0.5   3.0   9.5          0.057          0.0        0.000
#
#         Iso_failure  Bis_failure     Yield   E_factor  Material_cost  \
# 152767        0.004        0.568  0.915852  11.249094     563.878543
# 152767        0.004        0.568  0.915852  11.249094     563.878543
# 162028        0.006        0.929  0.917282   8.768832     449.466197
# 170848        0.032        0.983  0.917013   6.852799     361.082193
# 152767        0.004        0.568  0.915852  11.249094     563.878543
# ...             ...          ...       ...        ...            ...
# 130681        0.008        0.040  0.915370  18.473064     897.271329
# 130681        0.008        0.040  0.915370  18.473064     897.271329
# 130681        0.008        0.040  0.915370  18.473064     897.271329
# 130681        0.008        0.040  0.915370  18.473064     897.271329
# 148762        0.020        0.039  0.915564  11.237726     563.421436
#
#                STY  beta  flag  trial
# 152767  164.770097   0.1     1      0
# 152767  164.770097   0.1     1      0
# 162028  211.899351   0.1     1      0
# 170848  272.004193   0.1     1      0
# 152767  164.770097   0.1     1      0
# ...            ...   ...   ...    ...
# 130681   22.287471  20.0     1      4
# 130681   22.287471  20.0     0      4
# 130681   22.287471  20.0     0      4
# 130681   22.287471  20.0     0      4
# 148762   36.753630  20.0     1      4
#
# [100000 rows x 16 columns]

# %%
with open("random_sampling_range21.pickle", mode="wb") as f:
    pickle.dump(random_sampling_df, f)
with open("EPA_sampling_range21.pickle", mode="wb") as f:
    pickle.dump(EPA_sampling_df, f)
