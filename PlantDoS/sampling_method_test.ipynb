# %%
import numpy as np
import pandas as pd
import pickle
import copy
from sampling_method import random_sampling, population_annealing

# %%
with open('true_distribution_df_range21.pickle', 'rb') as p:
    true_distribution_df = pickle.load(p)

# %%
range_num = int(len(true_distribution_df)**(1/4))  #number of levels of each input parameters
random_num = 2000                                  #number of sampling in each trials
trial_num = 2                                      #number of trial

rs = random_sampling(true_distribution_df, range_num, random_num)
random_sampling_all_trial = rs.random_sample_from_df(trial_num)

# %%
random_sampling_all_trial
# Out:
#         Conc  SM2_eq  Temp  Time  Total_failure  SM1_failure  SM2_failure  \
# 63049    3.0     8.0  10.0   3.5            1.0          1.0          1.0
# 30896    1.5     3.5   0.5   2.5            1.0          1.0          1.0
# 90399    4.5     7.5  10.0   7.5            1.0          0.0          0.0
# 115659   6.0     5.0   2.5   6.0            1.0          1.0          1.0
# 30293    1.5     2.5   7.0   5.5            1.0          1.0          1.0
# ...      ...     ...   ...   ...            ...          ...          ...
# 157122   8.0    10.0   3.0   0.0            1.0          1.0          1.0
# 102632   5.5     0.5   7.5   2.5            1.0          1.0          1.0
# 46608    2.5     0.0   7.0   4.5            1.0          1.0          1.0
# 42513    2.0     6.0   4.0   4.5            1.0          1.0          1.0
# 2278     0.0     2.5   1.5   5.0            1.0          1.0          1.0
#
#         Iso_failure  Bis_failure     Yield     E_factor  Material_cost  \
# 63049          0.00          0.0  0.833699   149.331773    6934.884061
# 30896          0.00          0.0  0.033892  7805.770801  359600.369679
# 90399          0.09          1.0  0.890602    66.069573    3093.691618
# 115659         0.00          0.0  0.822349    33.977727    1611.734460
# 30293          0.00          0.0  0.715850   368.029156   17025.303254
# ...             ...          ...       ...          ...            ...
# 157122         0.00          0.0  0.496180    21.743102    1042.110404
# 102632         0.00          0.0  0.801958    44.670933    2105.245104
# 46608          0.00          0.0  0.705080   226.811061   10508.920005
# 42513          0.00          0.0  0.409652   501.974858   23195.640593
# 2278           0.00          0.0  0.089101  6268.609265  289003.756993
#
#                 STY  trial
# 63049     55.178248      0
# 30896      1.746973      0
# 90399     16.887851      0
# 115659    69.885668      0
# 30293      8.233132      0
# ...             ...    ...
# 157122  2302.234687      1
# 102632   305.439730      1
# 46608     22.043275      1
# 42513      9.974237      1
# 2278       0.621552      1
#
# [4000 rows x 14 columns]

# %%
range_num = int(len(true_distribution_df)**(1/4))  #number of levels of each input parameters
walk_step = 2                                      #number of random walk step (+-)
bnum = 10                                          #number of levels of inverse temperature
betas = np.linspace(0.1,20,num=bnum)               #inverse tenmeratures
mcmc_num = 20                                      #number of mcmc steps of each particles in one temperature
num_population = 10                                #number of population
trial_num = 2                                      #number of trial

pa = population_annealing(true_distribution_df,range_num,num_population,mcmc_num,walk_step,betas)
EPA_sampling_df, _EPA_sampling_df = pa.pupolation_annealing_from_df(trial_num)

# %%
EPA_sampling_df
# Out:
#         Conc  SM2_eq  Temp  Time  Total_failure  SM1_failure  SM2_failure  \
# 101863   5.0    10.0  10.0   6.5            1.0          0.0          0.0
# 101863   5.0    10.0  10.0   6.5            1.0          0.0          0.0
# 120386   6.0    10.0  10.0   7.0            1.0          0.0          0.0
# 101423   5.0     9.5  10.0   7.0            1.0          0.0          0.0
# 120386   6.0    10.0  10.0   7.0            1.0          0.0          0.0
# ...      ...     ...   ...   ...            ...          ...          ...
# 79001    4.0     5.5   1.0  10.0            1.0          1.0          1.0
# 79001    4.0     5.5   1.0  10.0            1.0          1.0          1.0
# 88283    4.5     5.5   1.5  10.0            1.0          1.0          1.0
# 79020    4.0     5.5   1.5   9.0            1.0          1.0          1.0
# 79021    4.0     5.5   1.5   9.5            1.0          1.0          1.0
#
#         Iso_failure  Bis_failure     Yield   E_factor  Material_cost  \
# 101863        0.002          1.0  0.884109  51.880952    2438.925601
# 101863        0.002          1.0  0.884109  51.880952    2438.925601
# 120386        0.001          1.0  0.869463  32.076848    1525.139216
# 101423        0.006          1.0  0.881372  52.042876    2446.427536
# 120386        0.001          1.0  0.869463  32.076848    1525.139216
# ...             ...          ...       ...        ...            ...
# 79001         0.000          0.0  0.852159  88.677668    4135.965981
# 79001         0.000          0.0  0.852159  88.677668    4135.965981
# 88283         0.000          0.0  0.890775  66.062369    3092.802180
# 79020         0.000          0.0  0.825947  91.527124    4267.224736
# 79021         0.000          0.0  0.852767  88.613082    4133.018045
#
#               STY  beta  flag  trial
# 101863  35.490913   0.1     1      0
# 101863  35.490913   0.1     1      0
# 120386  44.816327   0.1     1      0
# 101423  27.554768   0.1     1      0
# 120386  44.816327   0.1     1      0
# ...           ...   ...   ...    ...
# 79001    3.605534  20.0     1      1
# 79001    3.605534  20.0     1      1
# 88283    4.839388  20.0     1      1
# 79020    5.761669  20.0     1      1
# 79021    4.632900  20.0     1      1
#
# [4000 rows x 16 columns]
